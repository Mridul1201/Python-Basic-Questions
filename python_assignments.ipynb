# %% [markdown]
# #Python Assignment
#
# Q1. What is Python, and why is it popular?
#     -> Python is a popular programming language that is easy to learn and use. It looks a lot like English, which makes it simple for beginners to understand. People use Python to create websites, make games, analyze data, build apps, and even for artificial intelligence. One big reason Python is so popular is because it has many built-in tools and libraries that save time and make coding easier. Also, it works on different devices like Windows, Mac, and Linux. Big companies like Google and Netflix use Python, and there is a large community of people who can help if you get stuck. This makes Python a great choice for both beginners and professionals.
#
#
# Q2. What is an interpreter in Python?
#     -> An interpreter in Python is a special program that reads and runs your Python code line by line. Instead of turning the whole program into machine code at once (like a compiler does), the interpreter goes through each line, understands it, and then performs the action. This makes it easier to find and fix mistakes (called debugging), which is helpful for beginners. So, whenever you write and run a Python program, the interpreter is the one that understands your code and makes your computer do what you asked.
#
# Q3. What are pre-defined keywords in Python?
#     -> Pre defined keywords in python are inbuilt words that perform a specifc function, these words are already stored in python's interface and libraries and they are used to perform a speacial task which is assigned to them at default and make coding easier, keywords cannot be as variables because then the python mistakes them and doesnt run the code properly.
#
# Q4. Can keywords be used as variable names?
#     ->keywords cannot be as used as variable name because then the python mistakes them and doesnt run the code properly and beacuse the functions of keywords are already defined.
#
# Q5.  What is mutability in Python?
#     ->Mutability in Python means whether or not the value of an object can be changed after it is created. If an object can be changed, it is called mutable.
#
# Q6.  Why are lists mutable, but tuples are immutable?
#     ->In Python, lists are mutable while tuples are immutable because they are designed for different purposes. Lists are used when we need to store a collection of items that can change over time. You can add, remove, or modify elements in a list after it is created, which makes it flexible and useful for many situations. On the other hand, tuples are meant to store data that should stay the same. Once a tuple is created, its values cannot be changed. This immutability makes tuples more secure and slightly faster for the computer to process. So, Python provides both lists and tuples to give us the choice between flexibility and safety, depending on what we need in our program.
#
# Q7. What is the difference between “==” and “is” operators in Python?
#     ->  the "==" operator is a comparison operator in python, it is used to comapre two values simultaneously weather or not they are equal or not, whereas the is operator In Python, the is operator is used to check whether two variables refer to the same object in memory, not just whether their values are equal. This means it checks the identity of the objects. For example, if two variables point to the same list, a is b will return True. But if they have the same content but are stored separately, like two different lists with the same numbers, a is c will return False. So, the is operator is useful when you want to know if two variables are actually referring to the exact same object, not just two objects that look alike.
#
# Q8. What are logical operators in Python?
#     ->In Python, logical operators are used to combine multiple conditions and make decisions based on the combined result. There are three main logical operators: and, or, and not. The and operator returns True only if both conditions are true, while the or operator returns True if at least one of the conditions is true. The not operator reverses the result, returning True if the condition is false and False if the condition is true. These operators allow you to build more complex conditions, making them essential for decision-making in Python programs.
#
# Q9. What is type casting in Python?
#     ->Type casting in Python refers to the process of converting one data type into another. Python allows you to explicitly change the type of a variable using type casting functions. There are two main types: **implicit casting (automatic) and explicit casting (manual). Implicit casting happens automatically when Python converts one data type to another, like when you add an integer to a float, and Python automatically converts the integer to a float. On the other hand, explicit casting requires the use of built-in functions like `int()`, `float()`, or `str()` to manually convert a variable from one type to another. For example, `int(3.5)` will convert the floating-point number `3.5` to the integer `3`. Type casting is useful when you need to ensure variables are in the correct format for operations or when working with different types of data.
#
# Q10. What is the difference between implicit and explicit type casting?
#     ->There are two main types:implicit casting (automatic) and explicit casting (manual). Implicit casting happens automatically when Python converts one data type to another, like when you add an integer to a float, and Python automatically converts the integer to a float. On the other hand, explicit casting requires the use of built-in functions like `int()`, `float()`, or `str()` to manually convert a variable from one type to another. For example, `int(3.5)` will convert the floating-point number `3.5` to the integer `3`. Type casting is useful when you need to ensure variables are in the correct format for operations or when working with different types of data.
#
# Q11. What is the purpose of conditional statements in Python?
#     ->The purpose of conditional statements in Python is to allow the program to make decisions and execute certain blocks of code based on specific conditions. They help control the flow of execution by evaluating expressions and determining whether a certain action should be taken. The most commonly used conditional statements are if, elif, and else. The if statement checks if a condition is true, and if it is, it executes the corresponding block of code. The elif (else if) statement is used to check multiple conditions, and the else statement executes a block of code when none of the preceding conditions are true. Conditional statements are essential in programming as they enable the creation of dynamic programs that can adapt to different situations, making decisions based on input or other factors.
#
# Q12.  How does the elif statement work?
#     ->The elif statement in Python is used to check multiple conditions after an initial if statement. It stands for "else if," and it allows you to check for additional conditions if the previous if condition is false. The elif statement ensures that only one block of code is executed, even if multiple conditions are true. If the condition in the if statement is false, the program will move on to check the conditions in the elif blocks one by one. If any of the elif conditions are true, the corresponding block of code will be executed, and the rest will be skipped. If none of the if or elif conditions are true, the program will execute the code in the else block, if provided.
#
# Q13. What is the difference between for and while loops?
#     ->The main difference between a for loop and a while loop lies in how and when they are used. A for loop is generally used when the number of iterations is known beforehand. It is ideal for looping through sequences like lists, strings, or a range of numbers. The loop variable in a for loop is automatically updated with each iteration. On the other hand, a while loop is used when the number of repetitions is not known in advance and depends on a condition. It keeps running as long as the condition is True, and you have to manually update the variables involved, otherwise it may lead to an infinite loop. In short, use a for loop when you know how many times to run, and use a while loop when you need to keep checking a condition.
#
# Q14.  Describe a scenario where a while loop is more suitable than a for loop.
#     -> A while loop is more suitable in situations where you don’t know in advance how many times the loop needs to run, and the repetition depends on a certain condition being met. For example, imagine creating a program that keeps asking the user to guess a secret number until they get it right. Since you don’t know how many attempts the user will need, a `while` loop is ideal. It will keep running until the user inputs the correct answer. In this scenario, a `for` loop wouldn’t be as effective because you can’t predetermine the exact number of guesses required.

# %%
#Practical Questions

# Q1. Write a Python program to print "Hello, World!

print("Hello World");

# %%
# Q2. Write a Python program that displays your name and age.

Name = "Mridul";
Age= 21;
print("Name =",Name, "Age =" ,Age,);

# %%
# Q3. Write code to print all the pre-defined keywords in Python using the keyword library.
help('keywords')

# %%
#Q4. Write a program that checks if a given word is a Python keyword.
import keyword
word=input("Enter a word:");
if keyword.iskeyword(word):
  print(word,"is a keyword");
else:
  print(word,"is not a keyword");

# %%
#Q5.Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.
#list mutable
list=[1,2,3,4,5,6]
print(list)
list[0]=10
print(list)

#tuple immutable
tup=(1,2,3,4,5,6)
print(tup)
tup[0]=10
print(tup)
#error is thrown item assignment not possible in tuple

# %%
#Q6. Write a function to demonstrate the behavior of mutable and immutable arguments.


#list mutable
list=[1,2,3,4,5,6]
print(list)
list[0]=10
print(list)

#tuple immutable
tup=(1,2,3,4,5,6)
print(tup)
tup[0]=10
print(tup)
#error is thrown item assignment not possible in tuple

# %%
#Q7. Write a program that performs basic arithmetic operations on two user-input numbers.
no1= int(input("enter first no:"))
no2= int(input("enter second no:"))
sum= no1+no2;
sub= no1-no2;
mul= no1*no2;
div= no1/no2;
print("sum=",sum,"sub=",sub,"mul=",mul,"div=",div);

# %%
#Q8. Write a program to demonstrate the use of logical operators.
n=True
m=False
print(n and m)
print(n or m)
print( not n)
print( not m)

# %%
#Q9. Write a Python program to convert user input from string to integer, float, and boolean types.
n= input("enter the string")
print(int(n))
print(float(n))
print(bool(n))

# %%
#Q10.Write code to demonstrate type casting with list elements
n= 6
print(float(n))
print(str(n))
print(bool(n))

# %%
#Q11.Write a program that checks if a number is positive, negative, or zero.

no=int(input("enter no."))
if no>0:
  print("positive")
elif no<0:
  print("negative")
else:
  print("zero")

# %%
#Q12.Write a for loop to print numbers from 1 to 10.
for i in range(1,11):
  print(i)

# %%
#Q13.Write a Python program to find the sum of all even numbers between 1 and 50.)
sum=0
for i in range(1,51):
  if i%2==0:
    sum=sum+i
print(sum)

# %%
#Q14. Write a program to reverse a string using a while loop.
x= "Mridul"
while x in range (1,6,-1):
 print (x)

# %%
#Q15. Write a Python program to calculate the factorial of a number provided by the user using a while loop
no=int(input("enter the no:"))
fact=1
while no>0:
  fact=fact*no
  no=no-1
print(fact)
